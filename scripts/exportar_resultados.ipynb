# %% [markdown]
# ## Exportando o resultado de queries para arquivos CSV

# %% [markdown]
# Os resultados das principais queries serão salvos em arquivos CSV
# para futruramente serem utilizados em ferramentas de visualização
# como Power BI, Excel, ou até mesmo Python por meio da biblioteca Matplotlib

# %% [markdown]
# #### Setup Inicial

# %%
import os
import pandas as pd
import psycopg2
from io import StringIO
from dotenv import load_dotenv

load_dotenv()

USER = os.getenv('DB_USER')
PASSWORD = os.getenv('DB_PASSWORD')
HOST = os.getenv('DB_HOST')
PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')

conn = psycopg2.connect(
    dbname=f'{DB_NAME}',
    user=f'{USER}',
    password=f'{PASSWORD}',
    host=f'{HOST}',
    port=f'{PORT}'
)
cur = conn.cursor()

# %% [markdown]
# #### 1. Preço médio do GLP por Estado

# %%
# lendo o arquivo .sql
with open("../queries/exports/01_preco_medio_estado.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_preco_medio_estado.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 2. Variação do preço por Estado

# %%
with open("../queries/exports/02_amplitude_preco_estado.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_amplitude_preco_estado.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 3. Preço médio por Bandeira

# %%
with open("../queries/exports/03_preco_por_bandeira.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_preco_por_bandeira.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 4. Histórico de preço por bandeira com presença significativa (mais de 20 mil entradas)

# %%
with open("../queries/exports/04_hist_preco_bandeira.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_hist_preco_bandeira.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 5. Variação percentual mês a mês (MoM) do preço médio nacional

# %%
with open("../queries/exports/05_var_preco_nacional.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_var_preco_nacional.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 6. Ranking dos estados onde a média do preço foi maior que a média nacional

# %%
with open("../queries/exports/06_ranking_media_preco.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_ranking_media_preco.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# #### 7. Desvio médio histórico do preço em cada estado com relação à média nacional

# %%
with open("../queries/exports/07_desvio_medio_historico.sql", "r", encoding="utf-8") as f:
    query = f.read()

# salvando o resultado da query num arquivo CSV
with open("../data/results/output_desvio_medio_historico.csv", "w", encoding="utf-8") as f:
    cur.copy_expert(f"COPY ({query}) TO STDOUT WITH CSV HEADER", f)

# %% [markdown]
# fechando conexão com o banco de dados:

# %%
cur.close()
conn.close()
